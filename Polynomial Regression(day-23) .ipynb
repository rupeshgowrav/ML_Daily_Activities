# %% [markdown]
# # Polynomial Regression

# %% [markdown]
#  Polynomial Regression is a regression technique used to model a non-linear relationship between an independent variable and a dependent variable by expressing the input variable as a polynomial of degree greater than one, while still using linear regression to estimate efficients.

# %% [markdown]
# #### General Polynomial regression formula :
# - For degree(n):
# ![image.png](attachment:5e162a26-0a92-4677-9a9a-56e30535efed.png)
# - Quadratic degree :
# ![image.png](attachment:dd707106-d846-4ede-b3ca-acbdd896db81.png)

# %% [markdown]
#  ![image.png](attachment:99a5a780-0e85-4fac-b61b-b302860edfb7.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data = {
    'Study_Hours':[1,2,3,4,5],
    'Marks': [10,25,55,90,130]
}
df = pd.DataFrame(data)
df
# Out:
#    Study_Hours  Marks
# 0            1     10
# 1            2     25
# 2            3     55
# 3            4     90
# 4            5    130

# %%
x = df[['Study_Hours']]
y = df[['Marks']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=42)

# %%
poly = PolynomialFeatures(degree=2)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train_poly,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(x_test_poly)

# %%
print("Training MSE:", mean_squared_error(y_train,y_train_pred))
print("Testing MSE:", mean_squared_error(y_test,y_test_pred))
# Out:
# Training MSE: 2.3560645702600887e-28
# Testing MSE: 11.111111111110914

# %%
plt.scatter(x,y, color= 'blue', label='Actual Data')
x_line = np.linspace(min(x['Study_Hours']), max(x['Study_Hours']),100).reshape(-1,1)
y_line = model.predict(poly.transform(x_line))
plt.plot(x_line, y_line, color='red', label='Polynomial Fit')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Polynomial Regression Example')
plt.legend()
plt.show()
# Out:
# C:\Users\rupes\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
b0 = model.intercept_
b1 = model.coef_
b2 = model.coef_
print("b0 =", b0)
print("b1 =", b1)
print("b2 =", b2)
# Out:
# b0 = [1.42108547e-14]
# b1 = [[0.         5.83333333 4.16666667]]
# b2 = [[0.         5.83333333 4.16666667]]

# %%
x_new = pd.DataFrame({'Study_Hours': [6.0]})

x_new_poly = poly.transform(x_new)

y_new = model.predict(x_new_poly)

print("Predicted Value:", y_new)
# Out:
# Predicted Value: [[185.]]
